# %%
import requests, json, env
from requests.auth import HTTPBasicAuth


def getBearerToken(env: env):
	if env.token != "": return env.token

	print("no token")

	req = requests.post(
		url=f"{env.url}/webapi/rest/auth",
		auth=HTTPBasicAuth(env.login, env.password),
		headers={
			"Content-Type": "application/json",
		},
		data={
			"client_id": env.login,
			"client_secret": env.password
		}
	)

	token: str = f"Bearer {json.loads(req.content)['access_token']}"

	with open("./env.py") as file: 
		data = file.read()
		data = data.replace(
			data.split('\n')[-1],
			f'token: str = "{token}"'
		)

	with open("./env.py", "w") as file:
		file.write(data)

	return token

# %%
def errorHandler(data = False):
	if data != False:
		print(data)
	print("Unexpected error")

# %%
import env
from typing import Literal


token = getBearerToken(env)

def getMondraker(offset: int = 0) -> list | Literal[False]:
	req = requests.get(
		url=f"{env.url}/webapi/rest/products",
		headers={
			"Authorization": token,
			"Content-Type": "application/json",
		},
		params={
			"filters": json.dumps({
				"producer_id": 251
			}),
			"limit": 50,
			"offset": offset
		}
	)

	if not req.ok:
		errorHandler(req)
		return False
	return json.loads(req.content)

# %%
from typing import Literal
import math


def getAllMondraker() -> list | Literal[False]:
	firstReq: list | Literal[False] = getMondraker()
	if firstReq == False: return False

	allReq: int = math.ceil(int(firstReq["count"]) / 50)
	data: list = firstReq["list"]

	for i in range(1, allReq):
		req: list | Literal[False] = getMondraker(i * 50)

		if req == False: return data
		data += req["list"]

	return data

# %%
import env
from typing import Literal


token: str = getBearerToken(env)

def getStocksByProductsList(mondraker) -> dict[str, list | Literal[False]]:
	def getStock(id: int) -> list | Literal[False]:
		req = requests.get(
			url=f"{env.url}/webapi/rest/product-stocks",
			headers={
				"Authorization": token,
				"Content-Type": "application/json",
			},
			params={
				"filters": json.dumps({
					"product_id": id
				})
			}
		)

		if not req.ok:
			errorHandler(req)
			return False
		return json.loads(req.content)

	stocks: dict[str, list | Literal[False]] = {}

	for bike in mondraker:
		try:
			stocks[bike["additional_producer"]] = getStock(bike["product_id"])
		except:
			pass

	return stocks

# %%
from typing import Literal
import requests, xmltodict


def getB2BAvailability() -> dict | Literal[False]:
	bikes = requests.get(
		url="https://www.blizzardski.cz/b2b_feeds/feedy_prodejci/blizzard_b2b_MONDRAKER.xml",
		headers={ "Content-Type": "application/xml" }
	)
	availability = requests.get(
		url="https://www.blizzardski.cz/b2b_feeds/availability_product.xml",
		headers={ "Content-Type": "application/xml" }
	)
	if not bikes.ok or not availability.ok:
		errorHandler()
		return False

	bikes = xmltodict.parse(bikes.content)["SHOP"]["SHOPITEM"]
	availability = xmltodict.parse(availability.content)["item_list"]["item"]


	def findAvailabilityByEan(ean: str) -> dict | Literal[False]:
		for available in availability:
			if available["ean"] == ean:
				return available
		return False

	fixed: dict = {}

	for bike in bikes:
		availableSizes: dict = {}

		if isinstance(bike["VARIANT"], dict):
			available = findAvailabilityByEan(bike["VARIANT"]["EAN"])
			if not available: continue

			size: str = bike["VARIANT"]["VAL"].split(" ")[-1]
			availableSizes[size] = {
				**available,
				**bike["VARIANT"]
			}

		else:
			for variant in bike["VARIANT"]:
				available = findAvailabilityByEan(variant["EAN"])
				if not available: continue

				size: str = variant["VAL"].split(" ")[-1]
				availableSizes[size] = {
					**available,
					**variant
				}


		if availableSizes == {}: continue
		fixed[bike["ITEMGROUP_ID"]] = {
			"PRODUCT": bike["PRODUCT"],
			"ITEMGROUP_ID": bike["ITEMGROUP_ID"],
			"PARAM": availableSizes
		}

	return fixed

# %%
mondraker = getAllMondraker()

# %%
stocks = getStocksByProductsList(mondraker)

# %%
b2bAvailability = getB2BAvailability()

# %%
import json


def updateStockAvailability(id: str, stock: str):
	req = requests.put(
		url=f"{env.url}/webapi/rest/product-stocks/{id}",
		headers={
			"Authorization": token,
			"Content-Type": "application/json",
		},
		data=json.dumps({
			"stock": stock
		})
	)

	print(f"code: {req.status_code} ok: {req.ok} content: {req.content}")

# %%
import json


def isVariant(code: str) -> bool:
	code = code.upper()
	allowedEnds = ["-S", "-M", "-L", "-XL"]

	for chars in allowedEnds:
		if code[-len(chars):] == chars: return True

	return False


bikeWithNoStock = 0

for key, stock in stocks.items():

	###############################
	# NA CZAS DEBUGOWANIA
	#
	# do updatowania tylko i wyłącznie jednego produktu
	# kod: MD23009
	# Rozmiar: L
	###############################
	if key != "010.23121": continue
	isAvailable = False


	print(" ")
	try:
		print(b2bAvailability[key]["PRODUCT"])
	except:
		print("brak nazwy")

	for singleSize in stock["list"]:
		if not isVariant(singleSize["code"]): continue

		sizeId: str = singleSize["code"].split("-")[-1].upper()

		try:
			availability = b2bAvailability[key]["PARAM"][sizeId]["stock_quantity"]
			print(f"Rozmiar: {sizeId} Dostępność: {singleSize["stock"]} Hurtownia: {availability}")
			updateStockAvailability(singleSize["stock_id"], availability)
		except:
			print(f"Brak dostępności dla rozmiaru: {sizeId}")


		isAvailable = True

	if not isAvailable: bikeWithNoStock += 1

print(bikeWithNoStock)
# Out:
#
# MONDRAKER Foxy Carbon XR MIND, racing silver/yellow
# Brak dostępności dla rozmiaru: S
# Brak dostępności dla rozmiaru: M
# Rozmiar: L Dostępność: 0 Hurtownia: 1
# code: 200 ok: True content: b'1'
# Brak dostępności dla rozmiaru: XL
# 0

# %%
print(json.dumps(b2bAvailability, indent=2))
# Out:
# {
#   "010.23005": {
#     "PRODUCT": "MONDRAKER Chrono, desert grey/black",
#     "ITEMGROUP_ID": "010.23005",
#     "PARAM": {
#       "M": {
#         "@id": "27218",
#         "ean": "8435392857239",
#         "stock_quantity": "9",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "9",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857239",
#         "PRODUCTNO": "0000038140",
#         "VAL": "Velikost M"
#       },
#       "XL": {
#         "@id": "27973",
#         "ean": "8435392857253",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857253",
#         "PRODUCTNO": "0000038142",
#         "VAL": "Velikost XL"
#       },
#       "L": {
#         "@id": "27219",
#         "ean": "8435392857246",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857246",
#         "PRODUCTNO": "0000035256",
#         "VAL": "Velikost L"
#       },
#       "S": {
#         "@id": "27230",
#         "ean": "8435392857222",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392857222",
#         "PRODUCTNO": "0000038141",
#         "VAL": "Velikost S"
#       }
#     }
#   },
#   "010.23089": {
#     "PRODUCT": "MONDRAKER Raze Carbon RR, deep purple/light blue",
#     "ITEMGROUP_ID": "010.23089",
#     "PARAM": {
#       "L": {
#         "@id": "36028",
#         "ean": "8435392858083",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858083",
#         "PRODUCTNO": "0000041070",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23021": {
#     "PRODUCT": "MONDRAKER Chrono DC R, british racing green/yellow",
#     "ITEMGROUP_ID": "010.23021",
#     "PARAM": {
#       "L": {
#         "@id": "27969",
#         "ean": "8435392857406",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857406",
#         "PRODUCTNO": "0000038155",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "27970",
#         "ean": "8435392857413",
#         "stock_quantity": "5",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "5",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857413",
#         "PRODUCTNO": "0000038158",
#         "VAL": "Velikost XL"
#       },
#       "M": {
#         "@id": "29497",
#         "ean": "8435392857390",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857390",
#         "PRODUCTNO": "0000038156",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23332": {
#     "PRODUCT": "MONDRAKER Crafty R, marlin blue/black",
#     "ITEMGROUP_ID": "010.23332",
#     "PARAM": {
#       "M": {
#         "@id": "9114",
#         "ean": "8435392860185",
#         "stock_quantity": "5",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "5",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392860185",
#         "PRODUCTNO": "0000038190",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "8856",
#         "ean": "8435392860192",
#         "stock_quantity": "7",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "7",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392860192",
#         "PRODUCTNO": "0000038189",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23069": {
#     "PRODUCT": "MONDRAKER F-Podium Carbon DC RR, dirty white/racing silver",
#     "ITEMGROUP_ID": "010.23069",
#     "PARAM": {
#       "L": {
#         "@id": "36026",
#         "ean": "8435392857888",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392857888",
#         "PRODUCTNO": "0000041058",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23101": {
#     "PRODUCT": "MONDRAKER Foxy, black/nimbus grey/flame red",
#     "ITEMGROUP_ID": "010.23101",
#     "PARAM": {
#       "S": {
#         "@id": "9138",
#         "ean": "8435392858182",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858182",
#         "PRODUCTNO": "0000041074",
#         "VAL": "Velikost S"
#       },
#       "M": {
#         "@id": "9093",
#         "ean": "8435392858199",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858199",
#         "PRODUCTNO": "0000041073",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "9094",
#         "ean": "8435392858205",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858205",
#         "PRODUCTNO": "0000041072",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "9095",
#         "ean": "8435392858212",
#         "stock_quantity": "7",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "7",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858212",
#         "PRODUCTNO": "0000041075",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.24001": {
#     "PRODUCT": "MONDRAKER Chrono 29, bunker grey/flame red/vortex grey",
#     "ITEMGROUP_ID": "010.24001",
#     "PARAM": {
#       "XL": {
#         "@id": "36040",
#         "ean": "8435392876346",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876346",
#         "PRODUCTNO": "0000041096",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.24145": {
#     "PRODUCT": "MONDRAKER Superfoxy, carrera blue/navy blue",
#     "ITEMGROUP_ID": "010.24145",
#     "PARAM": {
#       "L": {
#         "@id": "34905",
#         "ean": "8435392877619",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392877619",
#         "PRODUCTNO": "0000038219",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "34906",
#         "ean": "8435392877602",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392877602",
#         "PRODUCTNO": "0000038220",
#         "VAL": "Velikost M"
#       },
#       "S": {
#         "@id": "34907",
#         "ean": "8435392877596",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392877596",
#         "PRODUCTNO": "0000038221",
#         "VAL": "Velikost S"
#       },
#       "XL": {
#         "@id": "34908",
#         "ean": "8435392877626",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392877626",
#         "PRODUCTNO": "0000038222",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.23153": {
#     "PRODUCT": "MONDRAKER Summum 29, dirty white/orange",
#     "ITEMGROUP_ID": "010.23153",
#     "PARAM": {
#       "M": {
#         "@id": "31019",
#         "ean": "8435392858717",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858717",
#         "PRODUCTNO": "0000043966",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23220": {
#     "PRODUCT": "MONDRAKER Thundra, cherry red/black",
#     "ITEMGROUP_ID": "010.23220",
#     "PARAM": {
#       "L": {
#         "@id": "33718",
#         "ean": "8435392859363",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392859363",
#         "PRODUCTNO": "0000035262",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23065": {
#     "PRODUCT": "MONDRAKER F-Podium Carbon DC R, marlin blue/carbon/racing silver",
#     "ITEMGROUP_ID": "010.23065",
#     "PARAM": {
#       "M": {
#         "@id": "9335",
#         "ean": "8435392857833",
#         "stock_quantity": "3",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "3",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857833",
#         "PRODUCTNO": "0000041056",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "9336",
#         "ean": "8435392857840",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857840",
#         "PRODUCTNO": "0000041055",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "27508",
#         "ean": "8435392857857",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392857857",
#         "PRODUCTNO": "0000041057",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.23117": {
#     "PRODUCT": "MONDRAKER Foxy Carbon RR MIND, carbon/desert grey/orange",
#     "ITEMGROUP_ID": "010.23117",
#     "PARAM": {
#       "L": {
#         "@id": "36984",
#         "ean": "8435392858366",
#         "stock_quantity": "4",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "4",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858366",
#         "PRODUCTNO": "0000043951",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.24421": {
#     "PRODUCT": "MONDRAKER Crafty Carbon R, bunker grey/carbon/yellow",
#     "ITEMGROUP_ID": "010.24421",
#     "PARAM": {
#       "L": {
#         "@id": "34942",
#         "ean": "8435392879798",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392879798",
#         "PRODUCTNO": "0000038257",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23205": {
#     "PRODUCT": "MONDRAKER Leader 24, racing silver/orange",
#     "ITEMGROUP_ID": "010.23205",
#     "PARAM": {
#       "24": {
#         "@id": "27280",
#         "ean": "8435392859226",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392859226",
#         "PRODUCTNO": "0000043977",
#         "VAL": "Velikost 24"
#       }
#     }
#   },
#   "010.23029": {
#     "PRODUCT": "MONDRAKER Chrono Carbon R, blue marlin/carbon/racing silver",
#     "ITEMGROUP_ID": "010.23029",
#     "PARAM": {
#       "L": {
#         "@id": "30215",
#         "ean": "8435392857482",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857482",
#         "PRODUCTNO": "0000038163",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "29869",
#         "ean": "8435392857475",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857475",
#         "PRODUCTNO": "0000038164",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23336": {
#     "PRODUCT": "MONDRAKER Crafty R, green",
#     "ITEMGROUP_ID": "010.23336",
#     "PARAM": {
#       "L": {
#         "@id": "27972",
#         "ean": "8435392860239",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392860239",
#         "PRODUCTNO": "0000038193",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "28396",
#         "ean": "8435392860222",
#         "stock_quantity": "4",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "4",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392860222",
#         "PRODUCTNO": "0000038194",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23388": {
#     "PRODUCT": "MONDRAKER Dusk, black/desert grey/orange",
#     "ITEMGROUP_ID": "010.23388",
#     "PARAM": {
#       "M": {
#         "@id": "36031",
#         "ean": "8435392860741",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392860741",
#         "PRODUCTNO": "0000041081",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "31873",
#         "ean": "8435392860758",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392860758",
#         "PRODUCTNO": "0000041080",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23235": {
#     "PRODUCT": "MONDRAKER Prime, black/nimbus grey/flame red",
#     "ITEMGROUP_ID": "010.23235",
#     "PARAM": {
#       "M": {
#         "@id": "8860",
#         "ean": "8435392859455",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392859455",
#         "PRODUCTNO": "0000035269",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "8861",
#         "ean": "8435392859462",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392859462",
#         "PRODUCTNO": "0000035268",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23251": {
#     "PRODUCT": "MONDRAKER Prime R, orange/dirty white",
#     "ITEMGROUP_ID": "010.23251",
#     "PARAM": {
#       "XL": {
#         "@id": "33724",
#         "ean": "8435392859578",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392859578",
#         "PRODUCTNO": "0000035277",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.24161": {
#     "PRODUCT": "MONDRAKER Super Foxy Carbon RR, bunker grey/denim blue/yellow",
#     "ITEMGROUP_ID": "010.24161",
#     "PARAM": {
#       "L": {
#         "@id": "34916",
#         "ean": "8435392877770",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392877770",
#         "PRODUCTNO": "0000038231",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.24286": {
#     "PRODUCT": "MONDRAKER Prime 29, nimbus grey/bronze/vortex grey",
#     "ITEMGROUP_ID": "010.24286",
#     "PARAM": {
#       "L": {
#         "@id": "37028",
#         "ean": "8435392878920",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392878920",
#         "PRODUCTNO": "0000044019",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "37031",
#         "ean": "8435392878937",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392878937",
#         "PRODUCTNO": "0000044022",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.23201": {
#     "PRODUCT": "MONDRAKER Factor 24, graphite/desert grey/orange",
#     "ITEMGROUP_ID": "010.23201",
#     "PARAM": {
#       "24": {
#         "@id": "28110",
#         "ean": "8435392859189",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392859189",
#         "PRODUCTNO": "0000043974",
#         "VAL": "Velikost 24"
#       }
#     }
#   },
#   "010.23053": {
#     "PRODUCT": "MONDRAKER F-Podium Carbon, carbon/orange",
#     "ITEMGROUP_ID": "010.23053",
#     "PARAM": {
#       "S": {
#         "@id": "27378",
#         "ean": "8435392857703",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857703",
#         "PRODUCTNO": "0000041047",
#         "VAL": "Velikost S"
#       },
#       "M": {
#         "@id": "9102",
#         "ean": "8435392857710",
#         "stock_quantity": "7",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "7",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857710",
#         "PRODUCTNO": "0000041046",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "9103",
#         "ean": "8435392857727",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857727",
#         "PRODUCTNO": "0000041045",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "9104",
#         "ean": "8435392857734",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857734",
#         "PRODUCTNO": "0000041048",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.24461": {
#     "PRODUCT": "MONDRAKER Level RR, flame red/vortex grey/racing silver",
#     "ITEMGROUP_ID": "010.24461",
#     "PARAM": {
#       "M": {
#         "@id": "34958",
#         "ean": "8435392880060",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392880060",
#         "PRODUCTNO": "0000038273",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23280": {
#     "PRODUCT": "MONDRAKER Chaser, graphite/black",
#     "ITEMGROUP_ID": "010.23280",
#     "PARAM": {
#       "L": {
#         "@id": "6097",
#         "ean": "8435392859752",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392859752",
#         "PRODUCTNO": "0000035286",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "8858",
#         "ean": "8435392859745",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392859745",
#         "PRODUCTNO": "0000035287",
#         "VAL": "Velikost M"
#       },
#       "XL": {
#         "@id": "8229",
#         "ean": "8435392859769",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392859769",
#         "PRODUCTNO": "0000035289",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.21081": {
#     "PRODUCT": "MONDRAKER Foxy Carbon R, blue/white/orange",
#     "ITEMGROUP_ID": "010.21081",
#     "PARAM": {
#       "S": {
#         "@id": "43668",
#         "ean": "8435392839341",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392839341",
#         "PRODUCTNO": "0000052881",
#         "VAL": "Velikost S"
#       }
#     }
#   },
#   "010.24029": {
#     "PRODUCT": "MONDRAKER Chrono Carbon DC, flame red/vortex grey/racing\u00a0silver",
#     "ITEMGROUP_ID": "010.24029",
#     "PARAM": {
#       "L": {
#         "@id": "36993",
#         "ean": "8435392876575",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876575",
#         "PRODUCTNO": "0000043984",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "36994",
#         "ean": "8435392876568",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876568",
#         "PRODUCTNO": "0000043985",
#         "VAL": "Velikost M"
#       },
#       "S": {
#         "@id": "36995",
#         "ean": "8435392876551",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876551",
#         "PRODUCTNO": "0000043986",
#         "VAL": "Velikost S"
#       },
#       "XL": {
#         "@id": "36996",
#         "ean": "8435392876582",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876582",
#         "PRODUCTNO": "0000043987",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.23211": {
#     "PRODUCT": "MONDRAKER F-Play 26, deep purple/black/light blue",
#     "ITEMGROUP_ID": "010.23211",
#     "PARAM": {
#       "26": {
#         "@id": "30989",
#         "ean": "8435392859288",
#         "stock_quantity": "4",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "4",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392859288",
#         "PRODUCTNO": "0000035259",
#         "VAL": "Velikost 26"
#       }
#     }
#   },
#   "010.22114SPE": {
#     "PRODUCT": "MONDRAKER Superfoxy Carbon R (SPE), dirty white/deep purple/flame red",
#     "ITEMGROUP_ID": "010.22114SPE",
#     "PARAM": {
#       "M": {
#         "@id": "51713",
#         "ean": "8435392855839",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392855839",
#         "PRODUCTNO": "0000060926",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23009": {
#     "PRODUCT": "MONDRAKER Chrono R, graphite/desert grey",
#     "ITEMGROUP_ID": "010.23009",
#     "PARAM": {
#       "L": {
#         "@id": "27639",
#         "ean": "8435392857284",
#         "stock_quantity": "9",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "9",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857284",
#         "PRODUCTNO": "0000038143",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "27976",
#         "ean": "8435392857277",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857277",
#         "PRODUCTNO": "0000038144",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23141": {
#     "PRODUCT": "MONDRAKER Superfoxy Carbon R, carbon/desert grey/orange",
#     "ITEMGROUP_ID": "010.23141",
#     "PARAM": {
#       "L": {
#         "@id": "28317",
#         "ean": "8435392858601",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858601",
#         "PRODUCTNO": "0000043961",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "27481",
#         "ean": "8435392858595",
#         "stock_quantity": "5",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "5",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858595",
#         "PRODUCTNO": "0000043962",
#         "VAL": "Velikost M"
#       },
#       "S": {
#         "@id": "32610",
#         "ean": "8435392858588",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858588",
#         "PRODUCTNO": "0000043963",
#         "VAL": "Velikost S"
#       },
#       "XL": {
#         "@id": "30506",
#         "ean": "8435392858618",
#         "stock_quantity": "3",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "3",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858618",
#         "PRODUCTNO": "0000043964",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.22300": {
#     "PRODUCT": "MONDRAKER Chaser 750, cherry red/black",
#     "ITEMGROUP_ID": "010.22300",
#     "PARAM": {
#       "M": {
#         "@id": "8956",
#         "ean": "8435392850292",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392850292",
#         "PRODUCTNO": "0000003466",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.24061": {
#     "PRODUCT": "MONDRAKER Podium Carbon RR SL 29, navy blue/white/marlin blue/flame red",
#     "ITEMGROUP_ID": "010.24061",
#     "PARAM": {
#       "L": {
#         "@id": "37013",
#         "ean": "8435392876773",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392876773",
#         "PRODUCTNO": "0000044004",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.24073": {
#     "PRODUCT": "MONDRAKER F-Podium Carbon R, bunker grey/flame red/vortex grey",
#     "ITEMGROUP_ID": "010.24073",
#     "PARAM": {
#       "L": {
#         "@id": "37021",
#         "ean": "8435392876896",
#         "stock_quantity": "5",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "5",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876896",
#         "PRODUCTNO": "0000044012",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "37022",
#         "ean": "8435392876889",
#         "stock_quantity": "4",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "4",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876889",
#         "PRODUCTNO": "0000044013",
#         "VAL": "Velikost M"
#       },
#       "XL": {
#         "@id": "37024",
#         "ean": "8435392876902",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876902",
#         "PRODUCTNO": "0000044015",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.22016SPE": {
#     "PRODUCT": "MONDRAKER Chrono R 29 (SPE), british racing green/yellow",
#     "ITEMGROUP_ID": "010.22016SPE",
#     "PARAM": {
#       "S": {
#         "@id": "19964",
#         "ean": "8435392855235",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392855235",
#         "PRODUCTNO": "0000014474",
#         "VAL": "Velikost S"
#       }
#     }
#   },
#   "010.23240": {
#     "PRODUCT": "MONDRAKER Prime, marlin blue/racing silver",
#     "ITEMGROUP_ID": "010.23240",
#     "PARAM": {
#       "XL": {
#         "@id": "28113",
#         "ean": "8435392859523",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392859523",
#         "PRODUCTNO": "0000035275",
#         "VAL": "Velikost XL"
#       },
#       "M": {
#         "@id": "28168",
#         "ean": "8435392859509",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392859509",
#         "PRODUCTNO": "0000035273",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23017": {
#     "PRODUCT": "MONDRAKER Chrono DC, graphite/desert grey/orange",
#     "ITEMGROUP_ID": "010.23017",
#     "PARAM": {
#       "S": {
#         "@id": "30419",
#         "ean": "8435392857345",
#         "stock_quantity": "8",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "8",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857345",
#         "PRODUCTNO": "0000038153",
#         "VAL": "Velikost S"
#       },
#       "L": {
#         "@id": "29613",
#         "ean": "8435392857369",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857369",
#         "PRODUCTNO": "0000038151",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "30420",
#         "ean": "8435392857376",
#         "stock_quantity": "9",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "9",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857376",
#         "PRODUCTNO": "0000038154",
#         "VAL": "Velikost XL"
#       },
#       "M": {
#         "@id": "28109",
#         "ean": "8435392857352",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857352",
#         "PRODUCTNO": "0000038152",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.24329": {
#     "PRODUCT": "MONDRAKER Chaser, fog grey/graphite grey/vortex grey",
#     "ITEMGROUP_ID": "010.24329",
#     "PARAM": {
#       "L": {
#         "@id": "37056",
#         "ean": "8435392879194",
#         "stock_quantity": "3",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "3",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392879194",
#         "PRODUCTNO": "0000044047",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "37057",
#         "ean": "8435392879187",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392879187",
#         "PRODUCTNO": "0000044048",
#         "VAL": "Velikost M"
#       },
#       "XL": {
#         "@id": "37059",
#         "ean": "8435392879200",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392879200",
#         "PRODUCTNO": "0000044050",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.22174": {
#     "PRODUCT": "MONDRAKER Prime 29, black/racing silver",
#     "ITEMGROUP_ID": "010.22174",
#     "PARAM": {
#       "L": {
#         "@id": "12928",
#         "ean": "8435392849050",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392849050",
#         "PRODUCTNO": "0000007438",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.22016": {
#     "PRODUCT": "MONDRAKER Chrono R 29, british racing green/yellow",
#     "ITEMGROUP_ID": "010.22016",
#     "PARAM": {
#       "M": {
#         "@id": "12531",
#         "ean": "8435392847452",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392847452",
#         "PRODUCTNO": "0000007041",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.24149": {
#     "PRODUCT": "MONDRAKER Superfoxy R, flame red/vortex grey/racing silver",
#     "ITEMGROUP_ID": "010.24149",
#     "PARAM": {
#       "XL": {
#         "@id": "34911",
#         "ean": "8435392877664",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392877664",
#         "PRODUCTNO": "0000038226",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.23284": {
#     "PRODUCT": "MONDRAKER Chaser, marlin blue/black",
#     "ITEMGROUP_ID": "010.23284",
#     "PARAM": {
#       "M": {
#         "@id": "6098",
#         "ean": "8435392859783",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392859783",
#         "PRODUCTNO": "0000038175",
#         "VAL": "Velikost M"
#       },
#       "XL": {
#         "@id": "28016",
#         "ean": "8435392859806",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392859806",
#         "PRODUCTNO": "0000038177",
#         "VAL": "Velikost XL"
#       },
#       "S": {
#         "@id": "9116",
#         "ean": "8435392859776",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392859776",
#         "PRODUCTNO": "0000038176",
#         "VAL": "Velikost S"
#       },
#       "L": {
#         "@id": "8859",
#         "ean": "8435392859790",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392859790",
#         "PRODUCTNO": "0000035290",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23061": {
#     "PRODUCT": "MONDRAKER F-Podium Carbon DC, nimbus grey/carbon/flame red",
#     "ITEMGROUP_ID": "010.23061",
#     "PARAM": {
#       "M": {
#         "@id": "9099",
#         "ean": "8435392857796",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857796",
#         "PRODUCTNO": "0000041053",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "9100",
#         "ean": "8435392857802",
#         "stock_quantity": "6",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "6",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857802",
#         "PRODUCTNO": "0000041052",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "9101",
#         "ean": "8435392857819",
#         "stock_quantity": "3",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "3",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857819",
#         "PRODUCTNO": "0000041054",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.24005": {
#     "PRODUCT": "MONDRAKER Chrono 29, graphite grey/black",
#     "ITEMGROUP_ID": "010.24005",
#     "PARAM": {
#       "L": {
#         "@id": "36041",
#         "ean": "8435392876377",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876377",
#         "PRODUCTNO": "0000041097",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.22052SPE": {
#     "PRODUCT": "MONDRAKER F-Podium Carbon DC (SPE), carbon/cherry red",
#     "ITEMGROUP_ID": "010.22052SPE",
#     "PARAM": {
#       "S": {
#         "@id": "51709",
#         "ean": "8435392855518",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392855518",
#         "PRODUCTNO": "0000060922",
#         "VAL": "Velikost S"
#       }
#     }
#   },
#   "010.24089": {
#     "PRODUCT": "MONDRAKER Raze, fog grey/nimbus grey/vortex grey",
#     "ITEMGROUP_ID": "010.24089",
#     "PARAM": {
#       "L": {
#         "@id": "33739",
#         "ean": "8435392877053",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392877053",
#         "PRODUCTNO": "0000035298",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23113": {
#     "PRODUCT": "MONDRAKER Foxy Carbon R, carbon/orange",
#     "ITEMGROUP_ID": "010.23113",
#     "PARAM": {
#       "S": {
#         "@id": "36983",
#         "ean": "8435392858304",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858304",
#         "PRODUCTNO": "0000043949",
#         "VAL": "Velikost S"
#       },
#       "M": {
#         "@id": "9091",
#         "ean": "8435392858311",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858311",
#         "PRODUCTNO": "0000043948",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "9092",
#         "ean": "8435392858328",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858328",
#         "PRODUCTNO": "0000043947",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "9122",
#         "ean": "8435392858335",
#         "stock_quantity": "7",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "7",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858335",
#         "PRODUCTNO": "0000043950",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.22012SPE": {
#     "PRODUCT": "MONDRAKER Chrono R 29 (SPE), cherry red/black",
#     "ITEMGROUP_ID": "010.22012SPE",
#     "PARAM": {
#       "XL": {
#         "@id": "13009",
#         "ean": "8435392855228",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392855228",
#         "PRODUCTNO": "0000007519",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.24333": {
#     "PRODUCT": "MONDRAKER Chaser, flame red/black/racing silver",
#     "ITEMGROUP_ID": "010.24333",
#     "PARAM": {
#       "XL": {
#         "@id": "37063",
#         "ean": "8435392879248",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392879248",
#         "PRODUCTNO": "0000044054",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.24069": {
#     "PRODUCT": "MONDRAKER F-Podium Carbon, carbon/carrera blue/midnight blue",
#     "ITEMGROUP_ID": "010.24069",
#     "PARAM": {
#       "L": {
#         "@id": "37017",
#         "ean": "8435392876858",
#         "stock_quantity": "5",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "5",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876858",
#         "PRODUCTNO": "0000044008",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "37018",
#         "ean": "8435392876841",
#         "stock_quantity": "5",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "5",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876841",
#         "PRODUCTNO": "0000044009",
#         "VAL": "Velikost M"
#       },
#       "S": {
#         "@id": "37019",
#         "ean": "8435392876834",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876834",
#         "PRODUCTNO": "0000044010",
#         "VAL": "Velikost S"
#       },
#       "XL": {
#         "@id": "37020",
#         "ean": "8435392876865",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876865",
#         "PRODUCTNO": "0000044011",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.23105": {
#     "PRODUCT": "MONDRAKER Foxy R, deep purple/light blue",
#     "ITEMGROUP_ID": "010.23105",
#     "PARAM": {
#       "XL": {
#         "@id": "27376",
#         "ean": "8435392858250",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858250",
#         "PRODUCTNO": "0000043946",
#         "VAL": "Velikost XL"
#       },
#       "L": {
#         "@id": "27377",
#         "ean": "8435392858243",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392858243",
#         "PRODUCTNO": "0000043943",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23392": {
#     "PRODUCT": "MONDRAKER Dusk R, deep purple/light blue",
#     "ITEMGROUP_ID": "010.23392",
#     "PARAM": {
#       "M": {
#         "@id": "32574",
#         "ean": "8435392860789",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392860789",
#         "PRODUCTNO": "0000041084",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "32575",
#         "ean": "8435392860796",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392860796",
#         "PRODUCTNO": "0000041083",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23415": {
#     "PRODUCT": "MONDRAKER Dusty R, desert grey/orange/carbon",
#     "ITEMGROUP_ID": "010.23415",
#     "PARAM": {
#       "L": {
#         "@id": "32128",
#         "ean": "8435392861014",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392861014",
#         "PRODUCTNO": "0000041085",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23025": {
#     "PRODUCT": "MONDRAKER Chrono Carbon, carbon/dirty white",
#     "ITEMGROUP_ID": "010.23025",
#     "PARAM": {
#       "L": {
#         "@id": "27223",
#         "ean": "8435392857444",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857444",
#         "PRODUCTNO": "0000038159",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "29612",
#         "ean": "8435392857437",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857437",
#         "PRODUCTNO": "0000038160",
#         "VAL": "Velikost M"
#       },
#       "S": {
#         "@id": "27224",
#         "ean": "8435392857420",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857420",
#         "PRODUCTNO": "0000038161",
#         "VAL": "Velikost S"
#       },
#       "XL": {
#         "@id": "27225",
#         "ean": "8435392857451",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857451",
#         "PRODUCTNO": "0000038162",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.23133": {
#     "PRODUCT": "MONDRAKER Superfoxy R, british racing green/racing silver/yellow",
#     "ITEMGROUP_ID": "010.23133",
#     "PARAM": {
#       "M": {
#         "@id": "27274",
#         "ean": "8435392858519",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858519",
#         "PRODUCTNO": "0000043958",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23121": {
#     "PRODUCT": "MONDRAKER Foxy Carbon XR MIND, racing silver/yellow",
#     "ITEMGROUP_ID": "010.23121",
#     "PARAM": {
#       "L": {
#         "@id": "36985",
#         "ean": "8435392858403",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858403",
#         "PRODUCTNO": "0000043952",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.22220": {
#     "PRODUCT": "MONDRAKER Crafty SE, black/marlin blue",
#     "ITEMGROUP_ID": "010.22220",
#     "PARAM": {
#       "XL": {
#         "@id": "12371",
#         "ean": "8435392849517",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392849517",
#         "PRODUCTNO": "0000006881",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.23037": {
#     "PRODUCT": "MONDRAKER Podium Carbon, translucent green carbon/racing silver",
#     "ITEMGROUP_ID": "010.23037",
#     "PARAM": {
#       "S": {
#         "@id": "27379",
#         "ean": "8435392857543",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857543",
#         "PRODUCTNO": "0000038173",
#         "VAL": "Velikost S"
#       },
#       "M": {
#         "@id": "9105",
#         "ean": "8435392857550",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857550",
#         "PRODUCTNO": "0000038172",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "9106",
#         "ean": "8435392857567",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857567",
#         "PRODUCTNO": "0000038171",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "9107",
#         "ean": "8435392857574",
#         "stock_quantity": "9",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "9",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857574",
#         "PRODUCTNO": "0000038174",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.24077": {
#     "PRODUCT": "MONDRAKER F-Podium Carbon RR, carbon/polaris/racing silver",
#     "ITEMGROUP_ID": "010.24077",
#     "PARAM": {
#       "M": {
#         "@id": "33732",
#         "ean": "8435392876926",
#         "stock_quantity": "5",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "5",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876926",
#         "PRODUCTNO": "0000035291",
#         "VAL": "Velikost M"
#       },
#       "S": {
#         "@id": "33733",
#         "ean": "8435392876919",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876919",
#         "PRODUCTNO": "0000035292",
#         "VAL": "Velikost S"
#       },
#       "XL": {
#         "@id": "33734",
#         "ean": "8435392876940",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876940",
#         "PRODUCTNO": "0000035293",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.22294": {
#     "PRODUCT": "MONDRAKER F-Play 24, cherry red-black",
#     "ITEMGROUP_ID": "010.22294",
#     "PARAM": {
#       "24": {
#         "@id": "19996",
#         "ean": "8435392850223",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392850223",
#         "PRODUCTNO": "0000043889",
#         "VAL": "Velikost 24"
#       }
#     }
#   },
#   "010.24291": {
#     "PRODUCT": "MONDRAKER Prime 29, flame red/vortex grey/racing silver",
#     "ITEMGROUP_ID": "010.24291",
#     "PARAM": {
#       "L": {
#         "@id": "37033",
#         "ean": "8435392878975",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392878975",
#         "PRODUCTNO": "0000044024",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23077": {
#     "PRODUCT": "MONDRAKER Raze, black/dirty white",
#     "ITEMGROUP_ID": "010.23077",
#     "PARAM": {
#       "S": {
#         "@id": "29495",
#         "ean": "8435392857949",
#         "stock_quantity": "6",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "6",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857949",
#         "PRODUCTNO": "0000041061",
#         "VAL": "Velikost S"
#       },
#       "M": {
#         "@id": "30418",
#         "ean": "8435392857956",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857956",
#         "PRODUCTNO": "0000041060",
#         "VAL": "Velikost M"
#       },
#       "XL": {
#         "@id": "29496",
#         "ean": "8435392857970",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857970",
#         "PRODUCTNO": "0000041062",
#         "VAL": "Velikost XL"
#       },
#       "L": {
#         "@id": "29379",
#         "ean": "8435392857963",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857963",
#         "PRODUCTNO": "0000041059",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.24117": {
#     "PRODUCT": "MONDRAKER Foxy 29, bunker grey/denim blue/navy blue",
#     "ITEMGROUP_ID": "010.24117",
#     "PARAM": {
#       "L": {
# ...
#         "@id": "33076",
#         "ean": "8435392851305",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392851305",
#         "PRODUCTNO": "0000043893",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "39564",
#         "ean": "8435392851312",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392851312",
#         "PRODUCTNO": "0000048777",
#         "VAL": "Velikost XL"
#       },
#       "M": {
#         "@id": "13232",
#         "ean": "8435392851299",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392851299",
#         "PRODUCTNO": "0000043894",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23129": {
#     "PRODUCT": "MONDRAKER Superfoxy, racing silver/blue marlin",
#     "ITEMGROUP_ID": "010.23129",
#     "PARAM": {
#       "S": {
#         "@id": "29648",
#         "ean": "8435392858465",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858465",
#         "PRODUCTNO": "0000043955",
#         "VAL": "Velikost S"
#       },
#       "L": {
#         "@id": "27266",
#         "ean": "8435392858489",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858489",
#         "PRODUCTNO": "0000043953",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "27123",
#         "ean": "8435392858472",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858472",
#         "PRODUCTNO": "0000043954",
#         "VAL": "Velikost M"
#       },
#       "XL": {
#         "@id": "27482",
#         "ean": "8435392858496",
#         "stock_quantity": "4",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "4",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858496",
#         "PRODUCTNO": "0000043956",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.24361": {
#     "PRODUCT": "MONDRAKER Crusher Carbon, nimbus grey/vortex grey/bronze",
#     "ITEMGROUP_ID": "010.24361",
#     "PARAM": {
#       "M": {
#         "@id": "33790",
#         "ean": "8435392879460",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392879460",
#         "PRODUCTNO": "0000035349",
#         "VAL": "Velikost M"
#       },
#       "S": {
#         "@id": "33791",
#         "ean": "8435392879453",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392879453",
#         "PRODUCTNO": "0000035350",
#         "VAL": "Velikost S"
#       }
#     }
#   },
#   "010.22179SPE": {
#     "PRODUCT": "MONDRAKER Prime 29 (SPE), marlin blue/black",
#     "ITEMGROUP_ID": "010.22179SPE",
#     "PARAM": {
#       "XS": {
#         "@id": "32578",
#         "ean": "8435392855969",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392855969",
#         "PRODUCTNO": "0000043887",
#         "VAL": "Velikost XS"
#       }
#     }
#   },
#   "010.24246": {
#     "PRODUCT": "MONDRAKER Neat RR, bunker grey/denim blue/yellow",
#     "ITEMGROUP_ID": "010.24246",
#     "PARAM": {
#       "M": {
#         "@id": "36080",
#         "ean": "8435392878555",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392878555",
#         "PRODUCTNO": "0000041136",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.22174SPE": {
#     "PRODUCT": "MONDRAKER Prime 29 (SPE), black/racing silver",
#     "ITEMGROUP_ID": "010.22174SPE",
#     "PARAM": {
#       "L": {
#         "@id": "13226",
#         "ean": "8435392855945",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392855945",
#         "PRODUCTNO": "0000007736",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.22096SPE": {
#     "PRODUCT": "MONDRAKER Summum Carbon R 29 MIND (SPE), carbon/green/yellow",
#     "ITEMGROUP_ID": "010.22096SPE",
#     "PARAM": {
#       "S": {
#         "@id": "51712",
#         "ean": "8435392855761",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392855761",
#         "PRODUCTNO": "0000060925",
#         "VAL": "Velikost S"
#       }
#     }
#   },
#   "010.22B304": {
#     "PRODUCT": "MONDRAKER Raze Carbon R, carbon/gloss black/racing silver",
#     "ITEMGROUP_ID": "010.22B304",
#     "PARAM": {
#       "L": {
#         "@id": "31595",
#         "ean": "8435392851183",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392851183",
#         "PRODUCTNO": "0000028747",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.24242": {
#     "PRODUCT": "MONDRAKER Neat R, carbon/racing silver/bronze",
#     "ITEMGROUP_ID": "010.24242",
#     "PARAM": {
#       "L": {
#         "@id": "36075",
#         "ean": "8435392878524",
#         "stock_quantity": "3",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "3",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392878524",
#         "PRODUCTNO": "0000041131",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "36076",
#         "ean": "8435392878517",
#         "stock_quantity": "7",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "7",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392878517",
#         "PRODUCTNO": "0000041132",
#         "VAL": "Velikost M"
#       },
#       "XL": {
#         "@id": "36078",
#         "ean": "8435392878531",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392878531",
#         "PRODUCTNO": "0000041134",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.23081": {
#     "PRODUCT": "MONDRAKER Raze R, idnight Blue / Crystal White / Flame Red",
#     "ITEMGROUP_ID": "010.23081",
#     "PARAM": {
#       "XL": {
#         "@id": "30481",
#         "ean": "8435392858014",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858014",
#         "PRODUCTNO": "0000041065",
#         "VAL": "Velikost XL"
#       },
#       "L": {
#         "@id": "29359",
#         "ean": "8435392858007",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858007",
#         "PRODUCTNO": "0000041063",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "29494",
#         "ean": "8435392857994",
#         "stock_quantity": "7",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "7",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857994",
#         "PRODUCTNO": "0000041064",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23161": {
#     "PRODUCT": "MONDRAKER Summum R 29, deep purple/light blue",
#     "ITEMGROUP_ID": "010.23161",
#     "PARAM": {
#       "M": {
#         "@id": "29611",
#         "ean": "8435392858793",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858793",
#         "PRODUCTNO": "0000043971",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23057": {
#     "PRODUCT": "MONDRAKER F-Podium Carbon R, carbon/british r green/racing silver",
#     "ITEMGROUP_ID": "010.23057",
#     "PARAM": {
#       "L": {
#         "@id": "36024",
#         "ean": "8435392857765",
#         "stock_quantity": "3",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "3",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857765",
#         "PRODUCTNO": "0000041049",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "27614",
#         "ean": "8435392857772",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392857772",
#         "PRODUCTNO": "0000041051",
#         "VAL": "Velikost XL"
#       },
#       "M": {
#         "@id": "36025",
#         "ean": "8435392857758",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857758",
#         "PRODUCTNO": "0000041050",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23001": {
#     "PRODUCT": "MONDRAKER Chrono, black/orange",
#     "ITEMGROUP_ID": "010.23001",
#     "PARAM": {
#       "S": {
#         "@id": "9108",
#         "ean": "8435392857185",
#         "stock_quantity": "7",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "7",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857185",
#         "PRODUCTNO": "0000035254",
#         "VAL": "Velikost S"
#       },
#       "M": {
#         "@id": "9109",
#         "ean": "8435392857192",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857192",
#         "PRODUCTNO": "0000035253",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "9110",
#         "ean": "8435392857208",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857208",
#         "PRODUCTNO": "0000035252",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "9111",
#         "ean": "8435392857215",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392857215",
#         "PRODUCTNO": "0000035255",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.23372": {
#     "PRODUCT": "MONDRAKER Level, cherry red/nimbus grey",
#     "ITEMGROUP_ID": "010.23372",
#     "PARAM": {
#       "L": {
#         "@id": "29609",
#         "ean": "8435392860598",
#         "stock_quantity": "3",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "3",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392860598",
#         "PRODUCTNO": "0000038208",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "28071",
#         "ean": "8435392860581",
#         "stock_quantity": "3",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "3",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392860581",
#         "PRODUCTNO": "0000038209",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.22304": {
#     "PRODUCT": "MONDRAKER Raze Carbon R MIND, carbon/gloss black/racing silver",
#     "ITEMGROUP_ID": "010.22304",
#     "PARAM": {
#       "M": {
#         "@id": "11060",
#         "ean": "8435392850339",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392850339",
#         "PRODUCTNO": "0000043891",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.22143": {
#     "PRODUCT": "MONDRAKER Prime R X, black/marlin blue",
#     "ITEMGROUP_ID": "010.22143",
#     "PARAM": {
#       "L": {
#         "@id": "14244",
#         "ean": "8435392849388",
#         "stock_quantity": "4",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "4",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392849388",
#         "PRODUCTNO": "0000043885",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "14275",
#         "ean": "8435392849395",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392849395",
#         "PRODUCTNO": "0000008785",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.24037": {
#     "PRODUCT": "MONDRAKER Chrono Carbon DC R, nimbus grey/black/dense\u00a0yellow",
#     "ITEMGROUP_ID": "010.24037",
#     "PARAM": {
#       "L": {
#         "@id": "36997",
#         "ean": "8435392876612",
#         "stock_quantity": "4",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "4",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876612",
#         "PRODUCTNO": "0000043988",
#         "VAL": "Velikost L"
#       },
#       "M": {
#         "@id": "36998",
#         "ean": "8435392876605",
#         "stock_quantity": "2",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "2",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392876605",
#         "PRODUCTNO": "0000043989",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.23085": {
#     "PRODUCT": "MONDRAKER Raze Carbon R, racing silver/orange",
#     "ITEMGROUP_ID": "010.23085",
#     "PARAM": {
#       "S": {
#         "@id": "36027",
#         "ean": "8435392858021",
#         "stock_quantity": "1",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "1",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858021",
#         "PRODUCTNO": "0000041068",
#         "VAL": "Velikost S"
#       },
#       "M": {
#         "@id": "9096",
#         "ean": "8435392858038",
#         "stock_quantity": "9",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "9",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858038",
#         "PRODUCTNO": "0000041067",
#         "VAL": "Velikost M"
#       },
#       "L": {
#         "@id": "9097",
#         "ean": "8435392858045",
#         "stock_quantity": "10",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "10",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858045",
#         "PRODUCTNO": "0000041066",
#         "VAL": "Velikost L"
#       },
#       "XL": {
#         "@id": "9098",
#         "ean": "8435392858052",
#         "stock_quantity": "6",
#         "delivery_date": "0",
#         "stock_quantity_VOTesin": "6",
#         "delivery_date_VOTesin": "0",
#         "EAN": "8435392858052",
#         "PRODUCTNO": "0000041069",
#         "VAL": "Velikost XL"
#       }
#     }
#   },
#   "010.24393": {
#     "PRODUCT": "MONDRAKER Crafty R, racing silver/flame red/vortex grey",
#     "ITEMGROUP_ID": "010.24393",
#     "PARAM": {
#       "M": {
#         "@id": "33806",
#         "ean": "8435392879620",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392879620",
#         "PRODUCTNO": "0000035365",
#         "VAL": "Velikost M"
#       }
#     }
#   },
#   "010.24121": {
#     "PRODUCT": "MONDRAKER Foxy R 29, graphite grey/bronze/fog grey",
#     "ITEMGROUP_ID": "010.24121",
#     "PARAM": {
#       "L": {
#         "@id": "33760",
#         "ean": "8435392877374",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392877374",
#         "PRODUCTNO": "0000035319",
#         "VAL": "Velikost L"
#       }
#     }
#   },
#   "010.23324": {
#     "PRODUCT": "MONDRAKER Crafty R, nimbus grey/black",
#     "ITEMGROUP_ID": "010.23324",
#     "PARAM": {
#       "M": {
#         "@id": "9113",
#         "ean": "8435392860109",
#         "stock_quantity": "0",
#         "delivery_date": "32",
#         "stock_quantity_VOTesin": "0",
#         "delivery_date_VOTesin": "32",
#         "EAN": "8435392860109",
#         "PRODUCTNO": "0000038186",
#         "VAL": "Velikost M"
#       }
#     }
#   }
# }
